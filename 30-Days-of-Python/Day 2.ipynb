# %% [markdown]
# ## DAY 2: 30 DAYS OF PYTHON

# %% [markdown]
# ### Level 1

# %%
First_Name = 'Sherif'
Last_Name = 'Bello'
Full_Name = First_Name + ' ' + Last_Name
Country = 'Nigeria'
City = 'Gombe'
Age = 33
Year = 2026
Is_Married = False
Is_True = True
is_Light_On = True
Multiple_Variables = First_Name, Last_Name, Country, City, Age, Year, Is_Married, Is_True, is_Light_On
print(First_Name)
print(Last_Name)
print(Full_Name)
print(Country)
print(City)
print(Age)
print(Year)
print(Is_Married)
print(Is_True)
print(is_Light_On)
print(Multiple_Variables)
# Out:
# Sherif
# Bello
# Sherif Bello
# Nigeria
# Gombe
# 33
# 2026
# False
# True
# True
# ('Sherif', 'Bello', 'Nigeria', 'Gombe', 33, 2026, False, True, True)

# %% [markdown]
# ### Level 2

# %%
1.
print(type(First_Name))
print(type(Last_Name))
print(type(Full_Name))
print(type(Country))
print(type(City))
print(type(Age))
print(type(Year))
print(type(Is_Married))
print(type(Is_True))
print(type(is_Light_On))
print(type(Multiple_Variables))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'tuple'>

# %%
2.
print(len(First_Name))
# Out:
# 6

# %%
3.
print('Length of First Name:', len(First_Name))
print('Length of Last Name:', len(Last_Name))
if len(First_Name) > len(Last_Name):
    print('First Name is longer.')
elif len(First_Name) < len(Last_Name):
    print('Last Name is longer.')
else:
    print('Both names have the same length.')
# Out:
# Length of First Name: 6
# Length of Last Name: 5
# First Name is longer.

# %%
4,5,6,7,8,9.
num_one = 5
num_two = 4
print('Sum:', num_one + num_two)
print('Difference:', num_one - num_two)
print('Product:', num_one * num_two)
print('Quotient:', num_one / num_two)
print('Floor Division:', num_one // num_two)
print('Exponent:', num_one ** num_two)
# Out:
# Sum: 9
# Difference: 1
# Product: 20
# Quotient: 1.25
# Floor Division: 1
# Exponent: 625

# %%
12.
The_radius_of_a_circle = 30  # meters
Area_of_a_circle = 3.14 * The_radius_of_a_circle ** 2
print('i.'' ''Area of the circle:', Area_of_a_circle,'\n')
circumference_of_a_circle = 2 * 3.14 * The_radius_of_a_circle
print('ii.'' ''Circumference of the circle:', circumference_of_a_circle,'\n')

radius=(input('Enter the radius of the circle: '))
area=3.14*float(The_radius_of_a_circle)**2
print('iii.'' ''Area of the circle:', area)
# Out:
# i. Area of the circle: 2826.0
#
# ii. Circumference of the circle: 188.4
#
# iii. Area of the circle: 2826.0

# %%
first_Name = 'Sherif'
last_Name = 'Bello'
country = 'Nigeria'
age = 33
print('First Name:', first_Name)
print('Last Name:', last_Name)
print('Country:', country)
print('Age:', age)
# Out:
# First Name: Sherif
# Last Name: Bello
# Country: Nigeria
# Age: 33

# %%
help ('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
