# %% [markdown]
# ## DAY 4: 30 DAYS OF PYTHON

# %%
String_1 = "Thirty"
String_2 = "Days"
String_3 = "Of"
String_4 = "Python"
Concacenated_string_1= String_1 + ' ' + String_2 + ' ' + String_3 + ' ' + String_4
print('1.', Concacenated_string_1)
# Out:
# 1. Thirty Days Of Python

# %%
string_1 = "Coding"
string_2 = "For"
string_3 = "All"
Concacenated_string_2 = string_1 + ' ' + string_2 + ' ' + string_3
print('2.', Concacenated_string_2)
# Out:
# 2. Coding For All

# %%
Company = Concacenated_string_2
print('4.', Company)
print('5.', (len(Company)))
print('6.', Company.upper())
print('7.', Company.lower())
print('8.', Company.capitalize())
print('  ', Company.title())
print('  ', Company.swapcase())
# Out:
# 4. Coding For All
# 5. 14
# 6. CODING FOR ALL
# 7. coding for all
# 8. Coding for all
#    Coding For All
#    cODING fOR aLL

# %%
print('9.', Company[0])
# Out:
# 9. C

# %%
Company = "Coding For All"
print('10.', Company.find('Coding'))
# Out:
# 10. 0

# %%
print('11.', Company.replace('Coding', 'Python'))
# Out:
# 11. Python For All

# %%
Company_1 = "Python For Everyone"
print('12.', Company_1.replace('Everyone', 'All'))
# Out:
# 12. Python For All

# %%
Conpany = "Coding For All"
print('13.', Conpany.split(" "))
# Out:
# 13. ['Coding', 'For', 'All']

# %%
Interface = ('Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon')
print('14.', Interface.split(','))
# Out:
# 14. ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']

# %%
Company = "Coding For All"
print('15.', Company[0])
print('16.', Company[-1])
print('17.', Company[10])
# Out:
# 15. C
# 16. l
# 17.

# %%
acronym = '18.' + ''.join(word[0] for word in Company_1.split())
print(acronym)
# Out:
# 18.PFE

# %%
acronym_1 ='19.' + ''.join(word[0] for word in Company.split())
print(acronym_1)
# Out:
# 19.CFA

# %%
Company = "Coding For All"
print('20.', Company.index('C'))
print('21.', Company.index('F'))
# Out:
# 20. 0
# 21. 7

# %%
Company_3 = "Coding For All People"
print('22.', Company_3.rfind('l'))
# Out:
# 22. 19

# %%
Sentence = "You cannot end a sentence with because because because is a conjunction"
print('23.', Sentence.index('because'))
print('24.', Sentence.rfind('because'))
print('25.', Sentence[31:54])
print('26.', Sentence.find('because'))
print('27.', Sentence[31:54])
# Out:
# 23. 31
# 24. 47
# 25. because because because
# 26. 31
# 27. because because because

# %%
Company = "Coding For All"
print('28.', Company.startswith('Coding'))
print('29.', Company.endswith('coding'),)
# Out:
# 28. True
# 29. False

# %%
Company = " Coding For All "
print('30.', Company.strip())
# Out:
# 30. Coding For All

# %%
Check = "30DaysOfPython"
print('31.', Check.isidentifier())
Check_1 = "thirty_days_of_python"
print('  ', Check_1.isidentifier())
# Out:
# 31. False
#    True

# %%
python_libraries = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print('32.', '# '.join(python_libraries))
# Out:
# 32. Django# Flask# Bottle# Pyramid# Falcon

# %%
sentence_1 = "I am enjoying this challenge."
sentence_2 = "I just wonder what is next."
print('33.', sentence_1,'\n','  ', sentence_2)
# Out:
# 33. I am enjoying this challenge.
#     I just wonder what is next.

# %%
print('34.', 'Name\tAge\tCountry\tCity')
print('   ','Sherif\t33\tNigeria\tGombe')
# Out:
# 34. Name	Age	Country	City
#     Sherif	33	Nigeria	Gombe

# %%
radius = 10
area = int(3.14 * radius ** 2)
formated_string = 'The area of a circle with radius {} is {} meter square.'.format(radius, area)
print('35.', formated_string)
# Out:
# 35. The area of a circle with radius 10 is 314 meter square.

# %%
a = 8
b = 6
print('{} + {} = {}'.format(a, b, a + b))
print('{} - {} = {}'.format(a, b, a - b))
print('{} * {} = {}'.format(a, b, a * b))
print('{} / {} = {:.2f}'.format(a, b, a / b))
print('{} % {} = {}'.format(a, b, a % b))
print('{} // {} = {}'.format(a, b, a // b))
print('{} ** {} = {}'.format(a, b, a ** b))
# Out:
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# 8 / 6 = 1.33
# 8 % 6 = 2
# 8 // 6 = 1
# 8 ** 6 = 262144
