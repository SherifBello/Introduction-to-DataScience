# %% [markdown]
# ## DAY 8: 30 DAYS OF PYTHON
# ### LEVEL ONE

# %%
Dog = {}
print(Dog)
# Out:
# {}

# %%
Dog["name"] = "Tiger"
Dog["color"] = "Brown"
Dog["breed"] = "German Shepherd"
Dog["legs"] = 4
Dog["age"] = 3
print(Dog)
# Out:
# {'name': 'Tiger', 'color': 'Brown', 'breed': 'German Shepherd', 'legs': 4, 'age': 3}

# %%
Student = {
    "First_name": "Abubakar",
    "Last_name": "Sani",
    "Gender": "Male",
    "Age": 30,
    "Marital_status": "Single",
    "Skills": ["Python", "Data Analysis", "Machine Learning"],
    "Country": "Nigeria",
    "City": "Gombe",
    "Address": "No 10, Jekadafari Street"
}
print(Student)
# Out:
# {'First_name': 'Abubakar', 'Last_name': 'Sani', 'Gender': 'Male', 'Age': 30, 'Marital_status': 'Single', 'Skills': ['Python', 'Data Analysis', 'Machine Learning'], 'Country': 'Nigeria', 'City': 'Gombe', 'Address': 'No 10, Jekadafari Street'}

# %%
print(len(Student))
# Out:
# 9

# %%
skills = Student.get("Skills")
print(skills)
print(type(skills))
# Out:
# ['Python', 'Data Analysis', 'Machine Learning']
# <class 'list'>

# %%
Student
Student['Skills'].append("Deep Learning")
print(Student['Skills'])
Student['Skills'].append('GIS')
print(Student['Skills'])
# Out:
# ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Deep Learning', 'Deep Learning', 'GIS', 'Deep Learning']
# ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Deep Learning', 'Deep Learning', 'GIS', 'Deep Learning', 'GIS']

# %%
print(Student.keys())
# Out:
# dict_keys(['First_name', 'Last_name', 'Gender', 'Age', 'Marital_status', 'Skills', 'Country', 'City', 'Address'])

# %%
print(Student.values())
# Out:
# dict_values(['Abubakar', 'Sani', 'Male', 30, 'Single', ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Deep Learning', 'Deep Learning', 'GIS', 'Deep Learning', 'GIS'], 'Nigeria', 'Gombe', 'No 10, Jekadafari Street'])

# %%
print(Student.items())
# Out:
# dict_items([('First_name', 'Abubakar'), ('Last_name', 'Sani'), ('Gender', 'Male'), ('Age', 30), ('Marital_status', 'Single'), ('Skills', ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Deep Learning', 'Deep Learning', 'GIS', 'Deep Learning', 'GIS']), ('Country', 'Nigeria'), ('City', 'Gombe'), ('Address', 'No 10, Jekadafari Street')])

# %%
Student.popitem()
print(Student)
# Out:
# {'First_name': 'Abubakar', 'Last_name': 'Sani', 'Gender': 'Male', 'Age': 30, 'Marital_status': 'Single', 'Skills': ['Python', 'Data Analysis', 'Machine Learning', 'Deep Learning', 'Deep Learning', 'Deep Learning', 'GIS', 'Deep Learning', 'GIS'], 'Country': 'Nigeria'}

# %%
del Dog
print(Dog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 del Dog
#       2 print(Dog)
#
# NameError: name 'Dog' is not defined
