# %% [markdown]
# ## DAY 15: 30 DAYS OF PYTHON
# ### PYTHON TYPE ERRORS EXERCISE

# %% [markdown]
# SYNTAX ERROR

# %%
print 'Hello, World!'
# Out:
#   Cell In[1], line 1
#     print 'Hello, World!'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# Name Error

# %%
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(age)
#
# NameError: name 'age' is not defined

# %%
age=25
print(age)
# Out:
# 25

# %% [markdown]
# Index Error

# %%
numbers = [1, 2, 3, 4, 5]
numbers[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 numbers = [1, 2, 3, 4, 5]
# ----> 2 numbers[5]
#
# IndexError: list index out of range

# %%
numbers[4]
# Out:
# 5

# %% [markdown]
# Module Not Found Error

# %%
import maths
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import maths
#
# ModuleNotFoundError: No module named 'maths'

# %%
import math

# %% [markdown]
# Attribute Error

# %%
math.PI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 math.PI
#
# AttributeError: module 'math' has no attribute 'PI'

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# Key Error

# %%
users = {'name':'Asab', 'Age':250, 'country':'Finland'}

# %%
users ['name']
users ['county']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 users ['name']
# ----> 2 users ['county']
#
# KeyError: 'county'

# %% [markdown]
# Type Error

# %%
5 + '15'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 5 + '15'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
5 + int('15')
# Out:
# 20

# %% [markdown]
# Import Error

# %%
from math import power
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from math import power
#
# ImportError: cannot import name 'power' from 'math' (unknown location)

# %%
from math import pow

# %% [markdown]
# Value Error

# %%
int('15a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 int('15a')
#
# ValueError: invalid literal for int() with base 10: '15a'

# %% [markdown]
# Zero Division Error

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### EXCEPTION HANDLING/PACKING UNPACKING EXERCISE

# %%
names = ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland', 'Estonia', 'Russia']
finland, sweden, norway, denmark, iceland, es, ru = names
nordic_countries = []
first_five = (finland, sweden, norway, denmark, iceland)
nordic_countries.append(first_five)
print(nordic_countries)
print(es)
print(ru)
# Out:
# [('Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland')]
# Estonia
# Russia
